# %% [markdown]
# <h2 align='center'>Data Visualization on Covid-19</h2>

# %% [markdown]
# <p align='center'><img src="https://www.fda.gov/files/covid19-1600x900.jpg" width='400'/>
# <img src="https://images.indianexpress.com/2021/02/COVID-19-positive-1200-1.jpg" width="400">

# %% [markdown]
# **Before proceeding with our analysis let us see basic information about the disease**
#
# What is Coronavirus disease?
#
# Coronavirus disease (COVID-19) is an infectious disease caused by the SARS-CoV-2 virus.
# Most people who fall sick with COVID-19 will experience mild to moderate symptoms and recover without special treatment. However, some will become seriously ill and require medical attention.
#
# How does it Spread?
#
# The virus can spread from an infected person’s mouth or nose in small liquid particles when they cough, sneeze, speak, sing or breathe. These particles range from larger respiratory droplets to smaller aerosols.
# You can be infected by breathing in the virus if you are near someone who has COVID-19, or by touching a contaminated surface and then your eyes, nose or mouth. The virus spreads more easily indoors and in crowded settings.
#
# for more details about Covid [click here](https://www.who.int/news-room/questions-and-answers/item/coronavirus-disease-covid-19-how-is-it-transmitted)

# %% [markdown]
# ### Note: This dataset has not been edited a lot only null values were changed into 0's and was made sure no change happened to the original datavalues

# %% [markdown]
# - Total Infection count in the world

# %% [markdown]
# <p align='center'><img src = "https://github.com/shadowmoon697/Data_visualization-of-Covid-19-using-Tableau/blob/main/pictures/Total%20worldwide.png?raw=true"/>

# %% [markdown]
# - Total Death count-Continent

# %% [markdown]
# <p align='center'><img src="https://github.com/shadowmoon697/Data_visualization-of-Covid-19-using-Tableau/blob/main/pictures/total%20death%20count-continent.png?raw=true"/>

# %% [markdown]
# - Infection rate-Location

# %% [markdown]
# <p align='center'><img src="https://github.com/shadowmoon697/Data_visualization-of-Covid-19-using-Tableau/blob/main/pictures/infection%20rate-location.png?raw=true"/>
#
# [Click here to check the values](https://public.tableau.com/app/profile/basavaraj.d4941/viz/infectionrate-location/Sheet1)

# %% [markdown]
# - Infection rate-top_20 locations

# %% [markdown]
# <p align='center'><img src="https://github.com/shadowmoon697/Data_visualization-of-Covid-19-using-Tableau/blob/main/pictures/infection%20rate-top%2020.png?raw=true"/>

# %% [markdown]
# - Infection Rate - year_and_month_wise

# %% [markdown]
# <p align='center'><img src="https://github.com/shadowmoon697/Data_visualization-of-Covid-19-using-Tableau/blob/main/pictures/infection%20rate-year%20wise.png?raw=true"/>
#
# [Click here to check values visually](https://public.tableau.com/app/profile/basavaraj.d4941/viz/infectionrate-yearwise/Sheet1)

# %% [markdown]
# - Total vaccination-Continent wise

# %% [markdown]
# <p align='center'><img src="https://github.com/shadowmoon697/Data_visualization-of-Covid-19-using-Tableau/blob/main/pictures/total%20vaccinations-continent.png?raw=true"/>

# %% [markdown]
# - Total vaccination-Location

# %% [markdown]
# <p align='center'><img src="https://github.com/shadowmoon697/Data_visualization-of-Covid-19-using-Tableau/blob/main/pictures/total%20vaccinations-location.png?raw=true"/>
#
# [Click here to check values](https://public.tableau.com/app/profile/basavaraj.d4941/viz/totalvaccinations-locations/Sheet1)

# %% [markdown]
# - Covid India- Total Count

# %% [markdown]
# <p align='center'><img src="https://github.com/shadowmoon697/Data_visualization-of-Covid-19-using-Tableau/blob/main/pictures/covid%20india-total.png?raw=true"/>

# %% [markdown]
# - Covid India-Day_wise

# %% [markdown]
# <p align='center'><img src="https://github.com/shadowmoon697/Data_visualization-of-Covid-19-using-Tableau/blob/main/pictures/covid%20india-day%20wise.png?raw=true"/>
#
# [Click here to check values](https://public.tableau.com/app/profile/basavaraj.d4941/viz/covidindia-daywise/Sheet3)

# %% [markdown]
# - Covid India-Location/State

# %% [markdown]
# <p align='center'><img src="https://github.com/shadowmoon697/Data_visualization-of-Covid-19-using-Tableau/blob/main/pictures/covid%20india-location.png?raw=true"/>
#
# [Click here for the values](https://public.tableau.com/app/profile/basavaraj.d4941/viz/covidindia-statewise/Sheet8)
